# %% [markdown]
# # Seaborn library

# %% [markdown]
# 1. provide a layer of abstraction hence simpler to use
# 2. better aesthetics
# 3. more graphics include

# %% [markdown]
# ## types of graph
# 1. figure level
# 2. axis level

# %% [markdown]
# ## classification of plots
# 1. relational:
#     1. Scatter plot
#     2. Line plot
# 2. Distribution Plot
#     1. Histogram plot
#     2. KDE Plot
#     3. rug plot
# 3. Categorical Plot
#     1. Bar plot
#     2. count Plot
#     3. Box Plot
#     4. Violin Plot
#     5. Swam Plot
# 4. Matrix plot
#     1. Heat Map
#     2. Cluster Map
# 5. Regression Plot
# 6. Multigrid plot
#     1. Joint plot
#     2. Pair Plot

# %% [markdown]
# ## Relational Plot
# * to See the statistical Relation Between 2 Or More Variables
# * Bivariate Analysis

# %% [markdown]
# ## Scatter Plot
#
# axes level

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express  as px

# %%
tips=pd.read_csv('tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='smoker',style='sex',size='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##  make scatter as figure level

# %% [markdown]
#  using replot

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',style='sex',size='size')

# %% [markdown]
# ## it is better to use figure level as we make multiple axes level

# %% [markdown]
# ## line plot

# %%
gap=px.data.gapminder()

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#filter data on country code
mask=gap['country']=='India'

# %%
temp_df=gap[mask]

# %%
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
#axes level
sns.lineplot(data=temp_df,x='year',y='lifeExp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
#using Relplot
sns.relplot(data=temp_df,x='year',y='lifeExp',kind='line')

# %%
sns.lineplot(data=gap,x='year',y='lifeExp',hue='country')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
##filter data for india pakistan and china
mask=gap['country'].isin(['India','Pakistan','China'])

# %%
df=gap[mask]

# %%
df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.relplot(data=df,x='year',y='lifeExp',kind='line',hue='country')

# %% [markdown]
# ## Distribution Plot
# 1. used for univariate Data
# 2. used to find out the Distribution
# 3. Range of the observation
# 4. Central Tendency
# 5. tells if data is bimodel
# 6. outliers

# %% [markdown]
# ## Histogram

# %%
# figure level -> displot
# axes level histplot

# %%
sns.histplot(data=tips,x='total_bill',bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x='total_bill',kind='hist',hue='sex')

# %%
sns.displot(data=tips,x='day',kind='hist')

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,x='age',kind='hist',element='step',hue='sex')

# %%
#facet col and row
sns.displot(data=titanic,x='age',kind='hist',element='step',hue='sex',col='sex')

# %% [markdown]
# ## KDE plot

# %%
#uses gaussian kernel to smoothen the function

sns.kdeplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,x='tip',kind='kde',hue='sex')

# %% [markdown]
# ## Rugplot

# %%
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Bivariate histogram

# %%
sns.histplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
## bivariate kde
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## heatmap

# %%
df=gap.pivot(index='country',columns='year',values='lifeExp')

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
d=gap[gap['continent']=='Europe']

# %%
df=d.pivot(index='country',columns='year',values='lifeExp')

# %%
sns.heatmap(df,annot=True,linewidths=0.5)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %% [markdown]
# ## Cluster Map

# %%
temp=pd.read_csv('iris.csv')

# %%
temp
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.clustermap(temp.iloc[:,[0,1,2,3]])

# %% [markdown]
# ## categorical

# %% [markdown]
# ### categorical scatter plot

# %% [markdown]
# #### strip plot

# %%
# strip plot
#axes level
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x='day',y='total_bill',jitter=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#level order
sns.catplot(data=tips,x='day',y='total_bill',kind='strip')

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',jitter=0.5)

# %% [markdown]
# #### swarm plot
