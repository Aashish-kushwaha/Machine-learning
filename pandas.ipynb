# %% [markdown]
# # pandas

# %% [markdown]
# pandas is a software library written for the python programming language for data manipulation and analysis. it offers data structures and operations for manipulating numerical tables and time series

# %% [markdown]
# Main Data Structures
# ## Data Frame: tabular
# ## Series: row or column in table

# %% [markdown]
# import numpy as np

# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()     #top 5 values
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
data.head(3)        #head basically give preview of data
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
# 1  normal           0    Chennai Super Kings           33               0
# 2  normal           0       Delhi Daredevils            0               9
#
#   player_of_match                                       venue    umpire1  \
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape
# Out:
# (577, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# ## fetching rows and columns

# %%
s=data['winner']
s
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 572    Royal Challengers Bangalore
# 573    Royal Challengers Bangalore
# 574            Sunrisers Hyderabad
# 575            Sunrisers Hyderabad
# 576            Sunrisers Hyderabad
# Name: winner, Length: 577, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
st=data[['team1','team2','winner']]
st
# Out:
#                      team1                        team2  \
# 0    Kolkata Knight Riders  Royal Challengers Bangalore
# 1      Chennai Super Kings              Kings XI Punjab
# 2         Rajasthan Royals             Delhi Daredevils
# 3           Mumbai Indians  Royal Challengers Bangalore
# 4          Deccan Chargers        Kolkata Knight Riders
# ..                     ...                          ...
# 572       Delhi Daredevils  Royal Challengers Bangalore
# 573          Gujarat Lions  Royal Challengers Bangalore
# 574    Sunrisers Hyderabad        Kolkata Knight Riders
# 575          Gujarat Lions          Sunrisers Hyderabad
# 576    Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ..                           ...
# 572  Royal Challengers Bangalore
# ...

# %%
type(st)
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[0]   #fetching row 1
# Out:
# id                                           1
# season                                    2008
# city                                 Bangalore
# date                                2008-04-18
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bangalore
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# result                                  normal
# dl_applied                                   0
# winner                   Kolkata Knight Riders
# win_by_runs                                140
# win_by_wickets                               0
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# umpire3                                    NaN
# Name: 0, dtype: object

# %%
data.iloc[1:3]
# Out:
#    id  season        city        date                team1             team2  \
# 1   2    2008  Chandigarh  2008-04-19  Chennai Super Kings   Kings XI Punjab
# 2   3    2008       Delhi  2008-04-19     Rajasthan Royals  Delhi Daredevils
#
#            toss_winner toss_decision  result  dl_applied               winner  \
# 1  Chennai Super Kings           bat  normal           0  Chennai Super Kings
# 2     Rajasthan Royals           bat  normal           0     Delhi Daredevils
#
#    win_by_runs  win_by_wickets player_of_match  \
# 1           33               0      MEK Hussey
# 2            0               9     MF Maharoof
#
#                                         venue    umpire1         umpire2  \
# 1  Punjab Cricket Association Stadium, Mohali  MR Benson      SL Shastri
# 2                            Feroz Shah Kotla  Aleem Dar  GA Pratapkumar
#
#    umpire3
# 1      NaN
# 2      NaN

# %%
data.iloc[[1,11,2]]
# Out:
#     id  season        city        date                  team1  \
# 1    2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 11  12    2008     Chennai  2008-04-26  Kolkata Knight Riders
# 2    3    2008       Delhi  2008-04-19       Rajasthan Royals
#
#                   team2            toss_winner toss_decision  result  \
# 1       Kings XI Punjab    Chennai Super Kings           bat  normal
# 11  Chennai Super Kings  Kolkata Knight Riders           bat  normal
# 2      Delhi Daredevils       Rajasthan Royals           bat  normal
#
#     dl_applied               winner  win_by_runs  win_by_wickets  \
# 1            0  Chennai Super Kings           33               0
# 11           0  Chennai Super Kings            0               9
# 2            0     Delhi Daredevils            0               9
#
#    player_of_match                                       venue    umpire1  \
# 1       MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
# ...

# %%
data.iloc[:,[4,5,10]]
# Out:
#                      team1                        team2  \
# 0    Kolkata Knight Riders  Royal Challengers Bangalore
# 1      Chennai Super Kings              Kings XI Punjab
# 2         Rajasthan Royals             Delhi Daredevils
# 3           Mumbai Indians  Royal Challengers Bangalore
# 4          Deccan Chargers        Kolkata Knight Riders
# ..                     ...                          ...
# 572       Delhi Daredevils  Royal Challengers Bangalore
# 573          Gujarat Lions  Royal Challengers Bangalore
# 574    Sunrisers Hyderabad        Kolkata Knight Riders
# 575          Gujarat Lions          Sunrisers Hyderabad
# 576    Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ..                           ...
# 572  Royal Challengers Bangalore
# ...

# %% [markdown]
# ## filtering dataframe basd on condition

# %%
#matches happened in hydrabad
mask=data['team1']=='Chennai Super Kings'
data[mask]
# Out:
#       id  season        city        date                team1  \
# 1      2    2008  Chandigarh  2008-04-19  Chennai Super Kings
# 7      8    2008     Chennai  2008-04-23  Chennai Super Kings
# 14    15    2008   Bangalore  2008-04-28  Chennai Super Kings
# 19    20    2008     Chennai  2008-05-02  Chennai Super Kings
# 23    24    2008      Jaipur  2008-05-04  Chennai Super Kings
# ..   ...     ...         ...         ...                  ...
# 487  488    2015     Chennai  2015-04-28  Chennai Super Kings
# 494  495    2015     Chennai  2015-05-04  Chennai Super Kings
# 499  500    2015     Chennai  2015-05-08  Chennai Super Kings
# 503  504    2015     Chennai  2015-05-10  Chennai Super Kings
# 505  506    2015      Raipur  2015-05-12  Chennai Super Kings
#
#                            team2            toss_winner toss_decision  result  \
# 1                Kings XI Punjab    Chennai Super Kings           bat  normal
# ...

# %%
data[mask].shape
# Out:
# (77, 18)

# %%
mask1=data['city']=='Chandigarh'
mask2=data['date']>'2008-04-19'
data[mask1 & mask2].head()
# Out:
#     id  season        city        date                        team1  \
# 9   10    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 13  14    2008  Chandigarh  2008-04-27             Delhi Daredevils
# 21  22    2008  Chandigarh  2008-05-03              Kings XI Punjab
# 34  35    2008  Chandigarh  2008-05-12  Royal Challengers Bangalore
# 37  38    2008  Chandigarh  2008-05-28              Kings XI Punjab
#
#                     team2                  toss_winner toss_decision  result  \
# 9          Mumbai Indians               Mumbai Indians         field  normal
# 13        Kings XI Punjab             Delhi Daredevils           bat  normal
# 21  Kolkata Knight Riders              Kings XI Punjab           bat  normal
# 34        Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 37       Rajasthan Royals             Rajasthan Royals         field  normal
#
#     dl_applied           winner  win_by_runs  win_by_wickets player_of_match  \
# ...

# %%
data[mask1 & mask2].shape
# Out:
# (41, 18)

# %%
mask1 = data['toss_winner'] == 'Mumbai Indians'
mask2 = data['winner'] == 'Mumbai Indians'
data[mask1 & mask2]['winner'].value_counts()
# Out:
# Mumbai Indians    41
# Name: winner, dtype: int64

# %% [markdown]
# ## ploting in pandas

# %%
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
mys=data['team1'].value_counts()
mys
# Out:
# Chennai Super Kings            77
# Mumbai Indians                 76
# Kings XI Punjab                69
# Kolkata Knight Riders          62
# Royal Challengers Bangalore    62
# Delhi Daredevils               57
# Rajasthan Royals               54
# Deccan Chargers                43
# Sunrisers Hyderabad            37
# Pune Warriors                  20
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Gujarat Lions                   6
# Name: team1, dtype: int64

# %%
mys['Gujarat Lions']
# Out:
# 6

# %%
data['team1'].value_counts()+data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# dtype: int64

# %% [markdown]
# ## sort values

# %%
#ascending
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Gujarat Lions                   16
# Pune Warriors                   46
# Sunrisers Hyderabad             62
# Deccan Chargers                 75
# Rajasthan Royals               118
# Chennai Super Kings            131
# Kolkata Knight Riders          132
# Delhi Daredevils               133
# Kings XI Punjab                134
# Royal Challengers Bangalore    139
# Mumbai Indians                 140
# dtype: int64

# %%
#descending
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# Chennai Super Kings            131
# Rajasthan Royals               118
# Deccan Chargers                 75
# Sunrisers Hyderabad             62
# Pune Warriors                   46
# Gujarat Lions                   16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 416  417    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 412  413    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 402  403    2014        NaN  2014-04-19               Mumbai Indians
# 403  404    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ## removing duplicates

# %%
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
data.drop_duplicates(subset=['city','season'])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 2      3    2008          Delhi  2008-04-19             Rajasthan Royals
# 3      4    2008         Mumbai  2008-04-20               Mumbai Indians
# 4      5    2008        Kolkata  2008-04-20              Deccan Chargers
# ..   ...     ...            ...         ...                          ...
# 524  525    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 532  533    2016           Pune  2016-04-22  Royal Challengers Bangalore
# 553  554    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 567  568    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 568  569    2016         Raipur  2016-05-20          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates(subset=['season'],keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 57     2008       Rajasthan Royals
# 114    2009        Deccan Chargers
# 174    2010    Chennai Super Kings
# 247    2011    Chennai Super Kings
# 321    2012  Kolkata Knight Riders
# 397    2013         Mumbai Indians
# 457    2014  Kolkata Knight Riders
# 516    2015         Mumbai Indians
# 576    2016    Sunrisers Hyderabad

# %% [markdown]
# ## groupby()

# %%
sector=data.groupby('city')

# %%
sector

# %%
len(data)
# Out:
# 577

# %%
len(sector)
# Out:
# 30

# %%
sector.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         58
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        42
# Chennai           48
# Cuttack            7
# Delhi             53
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         41
# Indore             2
# Jaipur            33
# Johannesburg       8
# Kanpur             2
# Kimberley          3
# Kochi              5
# Kolkata           54
# Mumbai            77
# Nagpur             3
# Port Elizabeth     7
# Pune              25
# Raipur             6
# Rajkot             5
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
sector.size().sort_values(ascending=False)
# Out:
# city
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Rajkot             5
# Nagpur             3
# Kimberley          3
# East London        3
# Indore             2
# Bloemfontein       2
# Kanpur             2
# dtype: int64

# %%
sector.first()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       399    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       121    2010  2010-03-15             Rajasthan Royals
# Bangalore         1    2008  2008-04-18        Kolkata Knight Riders
# Bloemfontein    102    2009  2009-05-15             Delhi Daredevils
# Cape Town        59    2009  2009-04-18               Mumbai Indians
# Centurion        74    2009  2009-04-28             Delhi Daredevils
# Chandigarh        2    2008  2008-04-19          Chennai Super Kings
# Chennai           8    2008  2008-04-23          Chennai Super Kings
# Cuttack         127    2010  2010-03-19              Deccan Chargers
# Delhi             3    2008  2008-04-19             Rajasthan Royals
# Dharamsala      166    2010  2010-04-16              Kings XI Punjab
# Durban           64    2009  2009-04-21              Kings XI Punjab
# ...

# %%
sector.last()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       417    2014  2014-04-29             Rajasthan Royals
# Ahmedabad       481    2015  2015-04-24             Rajasthan Royals
# Bangalore       577    2016  2016-05-29          Sunrisers Hyderabad
# Bloemfontein    106    2009  2009-05-17             Delhi Daredevils
# Cape Town        71    2009  2009-04-26              Kings XI Punjab
# Centurion       113    2009  2009-05-22             Delhi Daredevils
# Chandigarh      563    2016  2016-05-15              Kings XI Punjab
# Chennai         504    2015  2015-05-10          Chennai Super Kings
# Cuttack         438    2014  2014-05-14               Mumbai Indians
# Delhi           576    2016  2016-05-27                Gujarat Lions
# Dharamsala      391    2013  2013-05-18              Kings XI Punjab
# Durban          110    2009  2009-05-20          Chennai Super Kings
# ...

# %%
sector.groups
# Out:
# {'Abu Dhabi': [398, 400, 401, 405, 411, 412, 416], 'Ahmedabad': [120, 127, 135, 138, 422, 427, 438, 441, 466, 473, 476, 480], 'Bangalore': [0, 10, 14, 24, 30, 44, 51, 121, 124, 132, 137, 154, 157, 166, 182, 208, 220, 223, 231, 242, 252, 257, 266, 269, 290, 296, 307, 319, 323, 332, 341, 347, 351, 369, 372, 392, 421, 428, 432, 435, 450, 457, 465, 474, 478, 486, 490, 497, 511, 520, 527, 546, 551, 557, 560, 566, 573, 576], 'Bloemfontein': [101, 105], 'Cape Town': [58, 59, 60, 61, 64, 66, 70], 'Centurion': [73, 76, 77, 87, 88, 89, 96, 97, 106, 110, 111, 112], 'Chandigarh': [1, 9, 13, 21, 34, 37, 48, 117, 133, 136, 145, 155, 183, 196, 224, 227, 261, 270, 273, 280, 294, 306, 331, 340, 349, 376, 380, 388, 445, 449, 452, 484, 492, 506, 509, 519, 526, 529, 537, 552, 555, 562], 'Chennai': [7, 11, 19, 25, 31, 47, 50, 119, 130, 142, 146, 151, 162, 164, 175, 188, 202, 212, 216, 229, 237, 246, 247, 248, 260, 272, 274, 283, 287, 292, 304, 320, 321, 326, 336, 339, 350, 354, 358, 365, 386, 459, 461, 4
# ...

# %%
sector.get_group('Sharjah')
# Out:
#       id  season     city        date                  team1  \
# 399  400    2014  Sharjah  2014-04-17       Delhi Daredevils
# 404  405    2014  Sharjah  2014-04-20       Rajasthan Royals
# 406  407    2014  Sharjah  2014-04-22        Kings XI Punjab
# 408  409    2014  Sharjah  2014-04-24  Kolkata Knight Riders
# 413  414    2014  Sharjah  2014-04-27         Mumbai Indians
# 414  415    2014  Sharjah  2014-04-27    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 399  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 404              Kings XI Punjab              Kings XI Punjab         field
# 406          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 408  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 413             Delhi Daredevils               Mumbai Indians           bat
# 414          Chennai Super Kings          Sunrisers Hyderabad           bat
#
# ...

# %%
sector.sum()
# Out:
#                    id  season  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi        2850   14098           0          157              16
# Ahmedabad        4155   24156           0          180              38
# Bangalore       18611  116725           2         1202             202
# Bloemfontein      208    4018           0           14               6
# Cape Town         445   14063           1          145              18
# Centurion        1134   24108           1           81              49
# Chandigarh      12686   84514           0          536             151
# Chennai         12264   96554           0          715             111
# Cuttack          2121   14086           0           73              20
# Delhi           16210  106652           2          662             175
# Dharamsala       2418   18103           0          279              23
# Durban           1262   30135           1          159              33
# ...

# %%
sector.mean()
# Out:
#                         id       season  dl_applied  win_by_runs  \
# city
# Abu Dhabi       407.142857  2014.000000    0.000000    22.428571
# Ahmedabad       346.250000  2013.000000    0.000000    15.000000
# Bangalore       320.879310  2012.500000    0.034483    20.724138
# Bloemfontein    104.000000  2009.000000    0.000000     7.000000
# Cape Town        63.571429  2009.000000    0.142857    20.714286
# Centurion        94.500000  2009.000000    0.083333     6.750000
# Chandigarh      302.047619  2012.238095    0.000000    12.761905
# Chennai         255.500000  2011.541667    0.000000    14.895833
# Cuttack         303.000000  2012.285714    0.000000    10.428571
# Delhi           305.849057  2012.301887    0.037736    12.490566
# Dharamsala      268.666667  2011.444444    0.000000    31.000000
# Durban           84.133333  2009.000000    0.066667    10.600000
# East London      85.000000  2009.000000    0.000000    29.000000
# ...

# %%
sector['win_by_runs'].mean()
# Out:
# city
# Abu Dhabi         22.428571
# Ahmedabad         15.000000
# Bangalore         20.724138
# Bloemfontein       7.000000
# Cape Town         20.714286
# Centurion          6.750000
# Chandigarh        12.761905
# Chennai           14.895833
# Cuttack           10.428571
# Delhi             12.490566
# Dharamsala        31.000000
# Durban            10.600000
# East London       29.000000
# Hyderabad          9.024390
# Indore             0.000000
# Jaipur            13.939394
# Johannesburg       3.125000
# Kanpur             0.000000
# Kimberley         17.666667
# Kochi             22.000000
# Kolkata            8.870370
# Mumbai            13.740260
# Nagpur             5.000000
# Port Elizabeth    28.571429
# Pune              15.480000
# Raipur             3.500000
# Rajkot             4.600000
# Ranchi             5.857143
# Sharjah           12.333333
# Visakhapatnam     25.636364
# Name: win_by_runs, dtype: float64

# %%
df=pd.read_csv('deliveries.csv')

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
run=df.groupby('batsman')

# %%
run

# %%
type(run)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
run.get_group('DA Warner')
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 150283       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150284       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150288       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150291       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150292       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %% [markdown]
# number of balls played by warner

# %%
run.get_group('DA Warner').shape[0]  #number of balls played
# Out:
# 2902

# %% [markdown]
# ### top five batsman

# %%
run['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### batsman who hit most number of four

# %%
mask=df['batsman_runs']==4
newdf=df[mask]
newdf
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150403       636       2  Royal Challengers Bangalore
# 150407       636       2  Royal Challengers Bangalore
# 150418       636       2  Royal Challengers Bangalore
# 150447       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  \
# 2       Royal Challengers Bangalore     1     3      DA Warner
# 8       Royal Challengers Bangalore     2     2      DA Warner
# 13      Royal Challengers Bangalore     2     7   MC Henriques
# ...

# %%
#number of 4 in all ipl
newdf.shape[0]
# Out:
# 17033

# %%
newdf.groupby('batsman')['batsman_runs'].size().sort_values(ascending=False)
# Out:
# batsman
# G Gambhir         484
# SK Raina          402
# DA Warner         401
# S Dhawan          401
# V Kohli           384
#                  ...
# S Gopal             1
# DE Bollinger        1
# Sandeep Sharma      1
# Shivam Sharma       1
# KAJ Roach           1
# Name: batsman_runs, Length: 368, dtype: int64

# %% [markdown]
# #### virat most runs against teams

# %%
mask=df['batsman']=='V Kohli'

ndf=df[mask]
ndf
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
ndf.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %%
mask=df['bowling_team']=="Mumbai Indians"
new_df=df[mask]

# %%
new_df
# Out:
#         match_id  inning            batting_team    bowling_team  over  ball  \
# 373            2       2  Rising Pune Supergiant  Mumbai Indians     1     1
# 374            2       2  Rising Pune Supergiant  Mumbai Indians     1     2
# 375            2       2  Rising Pune Supergiant  Mumbai Indians     1     3
# 376            2       2  Rising Pune Supergiant  Mumbai Indians     1     4
# 377            2       2  Rising Pune Supergiant  Mumbai Indians     1     5
# ...          ...     ...                     ...             ...   ...   ...
# 148996       630       2           Gujarat Lions  Mumbai Indians    18     1
# 148997       630       2           Gujarat Lions  Mumbai Indians    18     2
# 148998       630       2           Gujarat Lions  Mumbai Indians    18     3
# 148999       630       2           Gujarat Lions  Mumbai Indians    18     4
# 149000       630       2           Gujarat Lions  Mumbai Indians    18     5
#
# ...

# %%
new_df.shape            #number of fours in all ipl combined
# Out:
# (18879, 21)

# %%
new_df.groupby('batsman')['batsman_runs'].size().sort_values(ascending=False)
# Out:
# batsman
# SK Raina          512
# MS Dhoni          442
# S Dhawan          432
# SE Marsh          408
# G Gambhir         402
#                  ...
# V Pratap Singh      1
# J Theron            1
# MM Patel            1
# Shahid Afridi       1
# AP Tare             1
# Name: batsman_runs, Length: 294, dtype: int64

# %%
mask1=df['batsman']=='S Dhawan'
sd=df[mask1]

# %%
sd.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 14         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     3
# 18         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     3
#
#     ball   batsman   non_striker       bowler  is_super_over  ...  bye_runs  \
# 5      6  S Dhawan     DA Warner     TS Mills              0  ...         0
# 6      7  S Dhawan     DA Warner     TS Mills              0  ...         0
# 7      1  S Dhawan     DA Warner  A Choudhary              0  ...         0
# 14     1  S Dhawan  MC Henriques     TS Mills              0  ...         0
# 18     5  S Dhawan  MC Henriques     TS Mills              0  ...         0
#
# ...

# %%
# we store it in sectors
s=sd.groupby('bowling_team')
len(s)
s.size().sort_values(ascending=False)
# Out:
# bowling_team
# Mumbai Indians                 432
# Kings XI Punjab                424
# Kolkata Knight Riders          415
# Chennai Super Kings            391
# Royal Challengers Bangalore    326
# Rajasthan Royals               294
# Delhi Daredevils               290
# Deccan Chargers                121
# Gujarat Lions                  109
# Rising Pune Supergiants         82
# Pune Warriors                   71
# Rising Pune Supergiant          41
# Kochi Tuskers Kerala             9
# dtype: int64

# %%
sd.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# bowling_team
# Mumbai Indians                 536
# Kings XI Punjab                530
# Kolkata Knight Riders          452
# Chennai Super Kings            448
# Royal Challengers Bangalore    399
# Name: batsman_runs, dtype: int64

# %%
# function to return the team particular batsman has scored most runs
def scored_runs(batsman_name):
    mask1=df['batsman']==batsman_name
    bt=df[mask1]
    return bt.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(1)

# %%
scored_runs('V Kohli')
# Out:
# bowling_team
# Chennai Super Kings    706
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ## isin() function

# %%
# find the most destructive batsman in death over in th history of IPL
#strike rate 
#min batsman 200 balls in over 16-20

# %%
mask=df['over']>15  #death over
death_overs=df[mask]

# %%
#find number of balls played by every batsman
allbt=death_overs.groupby('batsman')['batsman_runs'].count() #count of ball played by every batsman
mask=allbt>200          #batsman who played more than 200 balls
batsman_list=allbt[mask].index.tolist()   #list of batsman
len(batsman_list)
# Out:
# 43

# %%
#to find strike rate
#1.runs scored by all these 43 batsman
#2.balls played by batsman
final=df[df['batsman'].isin(batsman_list)]  #we check for every batsman is present in this list

# %%
#now in this final dataframe we need to calculate 
#1.runs scored
#2.balls played by these 43 batsman

# %%
runs=final.groupby('batsman')['batsman_runs'].sum()

# %%
balls=final.groupby('batsman')['batsman_runs'].count()

# %%
sr=(runs/balls)*100

# %%
sr
# Out:
# batsman
# A Mishra             89.005236
# AB de Villiers      145.129059
# AD Mathews          120.868114
# AM Rahane           117.486549
# AR Patel            122.672065
# AT Rayudu           123.014257
# BJ Hodge            121.422376
# DA Miller           137.709251
# DA Warner           138.318401
# DJ Bravo            122.286822
# DJ Hussey           120.072661
# DPMD Jayawardene    118.791064
# Harbhajan Singh     135.194585
# IK Pathan           116.751269
# JA Morkel           136.938202
# JH Kallis           105.936272
# JP Duminy           121.970624
# JP Faulkner         129.802956
# KA Pollard          140.621266
# KD Karthik          123.008475
# KM Jadhav           130.555556
# LRPL Taylor         120.070838
# MK Pandey           116.938453
# MK Tiwary           114.127424
# MS Dhoni            132.835821
# NV Ojha             114.528024
# P Kumar             105.263158
# PP Chawla           110.278373
# R Vinay Kumar       106.666667
# RA Jadeja           118.792867
# ...

# %% [markdown]
# ## merge function
# it join two data frame: hte condition is both dataframe should have something in common

# %%
df=pd.read_csv('deliveries.csv')
match=pd.read_csv('data.csv')
df.shape
# Out:
# (150460, 21)

# %%
#list of orange cap holder:the batsman who hit most run in a single season
#id is common in both data.csv and deliveries.csv
new=df.merge(match,left_on='match_id',right_on='id')

# %%
new.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='season',keep='first').sort_values('season')
# Out:
#     season       batsman  batsman_runs
# 6     2008     DA Warner           641
# 9     2009      SE Marsh           593
# 11    2010     ML Hayden           572
# 1     2011  SR Tendulkar           819
# 3     2012      CH Gayle           678
# 0     2013      CH Gayle           855
# 7     2014    MEK Hussey           624
# 5     2015    RV Uthappa           659
# 8     2016     AM Rahane           606

# %% [markdown]
# ## pivot table

# %%
#number of sixes by every team

# %%
mask=df['batsman_runs']==6
six=df[mask];
six.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
#
#     ball       batsman   non_striker       bowler  is_super_over  ...  \
# 10     4     DA Warner      S Dhawan  A Choudhary              0  ...
# 47     4  MC Henriques      S Dhawan      TM Head              0  ...
# 75     2  Yuvraj Singh  MC Henriques  A Choudhary              0  ...
# 89     3  Yuvraj Singh  MC Henriques    S Aravind              0  ...
# 91     5  MC Henriques  Yuvraj Singh    S Aravind              0  ...
#
#     bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
pt=six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='over'>

# %% [markdown]
# ## corelation funtion
# this function tells  how two function are different

# %%
#corr:calculation is doen only on numeric data
pi=match.corr()  #it give back pivot table

# %%
sns.heatmap(pi)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## reset columns name

# %%
match.rename(columns={'city':'palce'})
# Out:
#       id  season       palce        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# ## set_index and Reset_index

# %%
match.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
match.set_index('id')
# Out:
#      season        city        date                  team1  \
# id
# 1      2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 2      2008  Chandigarh  2008-04-19    Chennai Super Kings
# 3      2008       Delhi  2008-04-19       Rajasthan Royals
# 4      2008      Mumbai  2008-04-20         Mumbai Indians
# 5      2008     Kolkata  2008-04-20        Deccan Chargers
# ..      ...         ...         ...                    ...
# 573    2016      Raipur  2016-05-22       Delhi Daredevils
# 574    2016   Bangalore  2016-05-24          Gujarat Lions
# 575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 576    2016       Delhi  2016-05-27          Gujarat Lions
# 577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2                Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
data.reset_index()
# Out:
#      index   id  season        city        date                  team1  \
# 0        0    1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1        1    2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2        2    3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3        3    4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4        4    5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..     ...  ...     ...         ...         ...                    ...
# 572    572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573    573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574    574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575    575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576    576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data['winner'].value_counts().reset_index()
# Out:
#                           index  winner
# 0                Mumbai Indians      80
# 1           Chennai Super Kings      79
# 2   Royal Challengers Bangalore      70
# 3         Kolkata Knight Riders      68
# 4              Rajasthan Royals      63
# 5               Kings XI Punjab      63
# 6              Delhi Daredevils      56
# 7           Sunrisers Hyderabad      34
# 8               Deccan Chargers      29
# 9                 Pune Warriors      12
# 10                Gujarat Lions       9
# 11         Kochi Tuskers Kerala       6
# 12      Rising Pune Supergiants       5

# %% [markdown]
# ## Handling missing values

# %%
#1st way is to drop missing value row
# 2nd way is to fill them with some value

# %%
#dropna():
data=pd.read_csv('train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
